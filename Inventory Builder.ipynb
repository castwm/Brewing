# %%
import pandas as pd
#Pantry
labels = ['Ingredient', 'Category', 'Malt (lbs), Hops/Adjunct (oz), Yeast (packs)', 'Type']
weight_label = 'Malt (lbs), Hops/Adjunct (oz), Yeast (packs)'
inventory = []

# name is item, amount is amount, 
def add_hop(name, amount, classify, where_to):
    name = str(name)
    amount = amount
    package = str(classify)
    entry = [name, 'Hop', amount, package]
    where_to.append(entry)
    
def add_malt(name, amount, classify, where_to):
    name = str(name)
    amount = amount
    package = str(classify)
    entry = [name, 'Malt', amount, package]
    where_to.append(entry)

def add_yeast(name, amount, classify, where_to):
    name = str(name)
    amount = amount
    package = str(classify)
    entry = [name, 'Yeast', amount, package]
    where_to.append(entry)

def add_adjunct(name, amount, classify, where_to):
    name = str(name)
    amount = amount
    package = str(classify)
    entry = [name, 'Adjunct', amount, package]
    where_to.append(entry)
      
# add_other function for starsan bottles, and priming sugar

def title(name):
    name = name
    bold ='\033[1m'
    print(bold + name)
    
# Add Grains and Extracts
add_malt('Briess Pilsen M', 1.5, 'Grain', inventory)
add_malt('Goldpils Vienna Malt', 2, 'Grain', inventory)
add_malt('Light Roasted Barley', .75, 'Grain', inventory)
add_malt('Belgian Special', .75, 'Grain', inventory)
add_malt('Briess Carapils', .5, 'Grain', inventory)
add_malt('Two Row', 5, 'Grain', inventory)
add_malt('CBW Bavarian Wheat',6.6, 'Extract', inventory)

# Add Hops
add_hop('Hersbrucker', 1, 'Pellet', inventory)
add_hop('New Zealand Pacific Jade', 0.5, 'Pellet', inventory)
add_hop('Motueka', 0.5, 'Pellet', inventory)

# Add Yeasts
add_yeast('SafAle WB-06', 1, 'Dry', inventory)

pantry = pd.DataFrame(data = inventory, columns = labels)

title('Pantry')
pantry.head(len(pantry))
# Out:
# Pantry
#                   Ingredient Category  \
# 0            Briess Pilsen M     Malt
# 1       Goldpils Vienna Malt     Malt
# 2       Light Roasted Barley     Malt
# 3            Belgian Special     Malt
# 4            Briess Carapils     Malt
# 5                    Two Row     Malt
# 6         CBW Bavarian Wheat     Malt
# 7                Hersbrucker      Hop
# 8   New Zealand Pacific Jade      Hop
# 9                    Motueka      Hop
# 10              SafAle WB-06    Yeast
#
#     Malt (lbs), Hops/Adjunct (oz), Yeast (packs)     Type
# 0                                           1.50    Grain
# 1                                           2.00    Grain
# 2                                           0.75    Grain
# 3                                           0.75    Grain
# 4                                           0.50    Grain
# 5                                           5.00    Grain
# 6                                           6.60  Extract
# 7                                           1.00   Pellet
# 8                                           0.50   Pellet
# 9                                           0.50   Pellet
# 10                                          1.00      Dry

# %%
# Flagship Amber Ale Ingredients
amber_ale_ingredients = []

add_malt('Caramel 80L', 0.5, 'Grain', amber_ale_ingredients)
add_malt('Light Roasted Barley', 0.125, 'Grain', amber_ale_ingredients)
add_malt('Belgian Special', 0.125, 'Grain', amber_ale_ingredients)
add_malt('Briss Gold Malt Syrup', 6, 'Extract', amber_ale_ingredients)

add_hop('Willamette', 1, 'Pellet', amber_ale_ingredients)

add_yeast('Wyeast 1056', 1, 'Liquid', amber_ale_ingredients)
add_yeast('Muntons Ale Yeast', 1, 'Dry', amber_ale_ingredients)

amber_ale = pd.DataFrame(data = amber_ale_ingredients, columns = labels)
title('Amber Ale Recipe')
amber_ale.head(len(amber_ale))
# Out:
# Amber Ale Recipe
#               Ingredient Category  \
# 0            Caramel 80L     Malt
# 1   Light Roasted Barley     Malt
# 2        Belgian Special     Malt
# 3  Briss Gold Malt Syrup     Malt
# 4             Willamette      Hop
# 5            Wyeast 1056    Yeast
# 6      Muntons Ale Yeast    Yeast
#
#    Malt (lbs), Hops/Adjunct (oz), Yeast (packs)     Type
# 0                                         0.500    Grain
# 1                                         0.125    Grain
# 2                                         0.125    Grain
# 3                                         6.000  Extract
# 4                                         1.000   Pellet
# 5                                         1.000   Liquid
# 6                                         1.000      Dry

# %%
# Father's Day IPA
fathers_day_ipa_v1e_ingedients=[]

add_malt('Briess Pilsen M', 1.5, 'Grain', fathers_day_ipa_v1e_ingedients)
add_malt('Goldpils Vienna', 2, 'Grain', fathers_day_ipa_v1e_ingedients)
add_malt('Briess Carapils', 0.5, 'Grain', fathers_day_ipa_v1e_ingedients)
add_malt('Pilsen Malt Extract', 6.3, 'Extract', fathers_day_ipa_v1e_ingedients)

add_hop('Pacific Jade', 1.5, 'Pellet', fathers_day_ipa_v1e_ingedients)
add_hop('Motueka', 3, 'Pellet', fathers_day_ipa_v1e_ingedients)
add_hop('Nelson Sauvin', 1, 'Pellet', fathers_day_ipa_v1e_ingedients)
add_hop('Sorachi Ace', 1, 'Pellet', fathers_day_ipa_v1e_ingedients)

add_yeast('SafAle US-05', 1, 'Dry', fathers_day_ipa_v1e_ingedients)

fathers_day_ipa_v1e = pd.DataFrame(fathers_day_ipa_v1e_ingedients, columns = labels)

title("Father's Day IPA Version 1.Extract")
fathers_day_ipa_v1e.head(len(fathers_day_ipa_v1e))
# Out:
# Father's Day IPA Version 1.Extract
#             Ingredient Category  Malt (lbs), Hops/Adjunct (oz), Yeast (packs)  \
# 0      Briess Pilsen M     Malt                                           1.5
# 1      Goldpils Vienna     Malt                                           2.0
# 2      Briess Carapils     Malt                                           0.5
# 3  Pilsen Malt Extract     Malt                                           6.3
# 4         Pacific Jade      Hop                                           1.5
# 5              Motueka      Hop                                           3.0
# 6        Nelson Sauvin      Hop                                           1.0
# 7          Sorachi Ace      Hop                                           1.0
# 8         SafAle US-05    Yeast                                           1.0
#
#       Type
# 0    Grain
# 1    Grain
# 2    Grain
# 3  Extract
# 4   Pellet
# 5   Pellet
# 6   Pellet
# 7   Pellet
# 8      Dry

# %%
# American Hefeweizen
hefeweizen=[]

add_malt('CBW Bavarian Wheat', 6.6, 'Extract', hefeweizen)

add_hop('Hersbrucker', 1, 'Pellet', hefeweizen)

add_yeast('SafAle WB-06', 1, 'Dry', hefeweizen)

american_hef = pd.DataFrame(hefeweizen, columns = labels)

title("American Hefeweizen")
american_hef.head(len(american_hef))
# Out:
# American Hefeweizen
#            Ingredient Category  Malt (lbs), Hops/Adjunct (oz), Yeast (packs)  \
# 0  CBW Bavarian Wheat     Malt                                           6.6
# 1         Hersbrucker      Hop                                           1.0
# 2        SafAle WB-06    Yeast                                           1.0
#
#       Type
# 0  Extract
# 1   Pellet
# 2      Dry

# %%
#Recipes
flagship = amber_ale
fathers_day = fathers_day_ipa_v1e
ahef = american_hef

#ahef.head()

# %%
# Can I make this recipe?
drop = ['Category', 'Type']

# Change the recipe here by swapping out recipe = ...
recipe = flagship.drop(columns = drop)

pantry_compare = pantry.drop(columns = drop)

#print(recipe)
#print(pantry_compare)

make = recipe['Ingredient'].isin(pantry_compare['Ingredient'])
make = pd.Series(make)
inv = pd.DataFrame(data = list(make), columns = ['Available'])
#print(inv.head(len(inv)))

recipe.rename(columns ={weight_label: 'Recipe Amount'}, 
                    inplace = True)
pantry_compare.rename(columns = {weight_label: 'In Inventory'},
                      inplace = True)

yummy_beer = recipe.join(inv)
yummy_beer.head(len(recipe))
# Out:
#               Ingredient  Recipe Amount  Available
# 0            Caramel 80L          0.500      False
# 1   Light Roasted Barley          0.125       True
# 2        Belgian Special          0.125       True
# 3  Briss Gold Malt Syrup          6.000      False
# 4             Willamette          1.000      False
# 5            Wyeast 1056          1.000      False
# 6      Muntons Ale Yeast          1.000      False

# %%
def make_beer(beer):
    beer = beer
    beer[weight_label] *= -1
    return beer

new_amber = make_beer(amber_ale)
#print(new_amber)

pantry = pantry.append(new_amber)

pantry.head(len(pantry))
pantry.set_index('Ingredient')
# Out:
#                          Category  \
# Ingredient
# Briess Pilsen M              Malt
# Goldpils Vienna Malt         Malt
# Light Roasted Barley         Malt
# Belgian Special              Malt
# Briess Carapils              Malt
# Two Row                      Malt
# CBW Bavarian Wheat           Malt
# Hersbrucker                   Hop
# New Zealand Pacific Jade      Hop
# Motueka                       Hop
# SafAle WB-06                Yeast
# Caramel 80L                  Malt
# Light Roasted Barley         Malt
# Belgian Special              Malt
# Briss Gold Malt Syrup        Malt
# Willamette                    Hop
# Wyeast 1056                 Yeast
# Muntons Ale Yeast           Yeast
#
#                           Malt (lbs), Hops/Adjunct (oz), Yeast (packs)  \
# Ingredient
# Briess Pilsen M                                                  1.500
# Goldpils Vienna Malt                                             2.000
# Light Roasted Barley                                             0.750
# Belgian Special                                                  0.750
# Briess Carapils                                                  0.500
# Two Row                                                          5.000
# CBW Bavarian Wheat                                               6.600
# Hersbrucker                                                      1.000
# New Zealand Pacific Jade                                         0.500
# Motueka                                                          0.500
# SafAle WB-06                                                     1.000
# Caramel 80L                                                     -0.500
# Light Roasted Barley                                            -0.125
# Belgian Special                                                 -0.125
# Briss Gold Malt Syrup                                           -6.000
# Willamette                                                      -1.000
# Wyeast 1056                                                     -1.000
# Muntons Ale Yeast                                               -1.000
#
#                              Type
# Ingredient
# Briess Pilsen M             Grain
# Goldpils Vienna Malt        Grain
# Light Roasted Barley        Grain
# Belgian Special             Grain
# Briess Carapils             Grain
# Two Row                     Grain
# CBW Bavarian Wheat        Extract
# Hersbrucker                Pellet
# New Zealand Pacific Jade   Pellet
# Motueka                    Pellet
# SafAle WB-06                  Dry
# Caramel 80L                 Grain
# Light Roasted Barley        Grain
# Belgian Special             Grain
# Briss Gold Malt Syrup     Extract
# Willamette                 Pellet
# Wyeast 1056                Liquid
# Muntons Ale Yeast             Dry
